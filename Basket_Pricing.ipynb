# %%
#libraries
#----------------------------------------------------------------------------
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import os
import time
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.models import Model
#----------------------------------------------------------------------------

# %% [markdown]
# # Build and train a neural network model for pricing European Basket options under Black-Scholes assumptions.
#
# In order to train a neural network we will need to generate data.
#
# 1.   Data Generation
# 2.   Building Model
#
# **Methodology**
#
# The first step is to create a set of combinations of model, option and market parameters (strike, maturities, volatility, riskfree rate, ...)
#
# For the multi-asset case (basket option), the Scipy implementation of the numerically stable algorithm of Davies &
# Higham is used to generate random correlation matrices of
# underlyings.

# %%
#Global Variables :

#number of epochs to train the model on
EPOCHS = 50

BASE_PRICE   = 100
BASE_STRIKE  = 200

#random correlation matrices of underlyings assuming we are working with 3 assets
CORR = stats.random_correlation.rvs((1, .8, 1.2))

# %%
class BasketOption:
  """
  Basket class
  """
  def __init__(self, weights, prices, volatility, corr, strike, maturity, rate):
    """
    args:
    - matuity : in years
    """
    self.weights = weights
    self.vol = volatility
    self.strike = strike
    self.mat = maturity
    self.rate = rate
    self.corr = corr
    self.prices = prices


  def get_mc(self, M=10000):

    '''
    reference : https://github.com/shrentseng/Numerical-methods-for-option-pricing/blob/main/Monte%20Carlo%20simulation%20option%20pricing.ipynb
    runs M paths of MC

    '''
    #B_Ts = np.random.normal(0, self.mat, M)
    B_Ts = stats.multivariate_normal(np.zeros(len(self.weights)), cov=self.corr).rvs(size=M)
    S_Ts = self.prices * np.exp((self.rate - 0.5 * self.vol ** 2) * self.mat + self.vol * B_Ts)
    if len(self.weights) > 1:
      payoffs = (np.sum(self.weights * S_Ts, axis=1) - self.strike).clip(0)
    else:
      payoffs = np.maximum(S_Ts - self.strike, np.zeros(M))
    self.mc_price = np.mean(payoffs)
    return np.exp(-1 * self.rate * self.mat) * self.mc_price


  def get_bs_price(self):
        d1 = 1 / (self.vol * (self.mat) ** 0.5) * (np.log(self.prices/self.strike)\
                                            + (self.rate + (0.5 * self.vol ** 2)) * self.mat)
        d2 = d1 - self.vol * self.mat ** 0.5
        self.bs_price = stats.norm.cdf(d1) * self.prices\
                        - stats.norm.cdf(d2) * self.strike * np.exp(-self.rate * self.mat)

        return self.bs_price

# %%
class DataGen:
  """
  Based on the class Basket option
  This class will simulate multiple baskets to train our model on
  """
  def __init__(self, n_assets, n_samples):
    """
    n_assets: number of assets contained in a portfolio ( basket )
    n_samples : number of baskets we are simulating
    """
    self.n_assets = n_assets
    self.n_samples = n_samples

    if (self.n_samples <= 0):
      raise ValueError("n_samples needs to be positive")

    if (self.n_assets <= 0):
      raise ValueError("n_assets needs to be positive")


  def generate(self, corr=CORR, strike_price=BASE_STRIKE, base_price=BASE_PRICE, method='bs'):
    """
    - method : refers to the solver that will compute the labels
    it can be "bs" : for Black-Scholes or "mc" : Monte Carlo

    """

    mats = np.random.uniform(0.2, 1.1, size=self.n_samples)
    vols = np.random.uniform(0.01, 1, size=self.n_samples)
    rates = np.random.uniform(0.02, 0.1, size=self.n_samples)

    #add noise to strikes and prices
    strikes = np.random.randn(self.n_samples) + strike_price
    prices  = np.random.randn(self.n_samples) + base_price

    if self.n_assets > 1:
      weights = np.random.rand(self.n_samples * self.n_assets).reshape((self.n_samples, self.n_assets))
      weights /= np.sum(weights, axis=1)[:, np.newaxis]
    else:
      weights = np.ones((self.n_samples, self.n_assets))

    labels = []
    for i in range(self.n_samples):
      basket = BasketOption(weights[i], prices[i],
                                  vols[i], corr, strikes[i],
                                  mats[i], rates[i])
      if method == "bs":
        labels.append(basket.get_bs_price())
      else:
        labels.append(basket.get_mc())

    print(len(labels))
    self.data = pd.DataFrame({
                         'S/K' : prices / strikes,
                         'Maturity': mats,
                         'Volatility': vols,
                         'Rate': rates,
                         'Labels': labels,
                         'Prices': prices,
                         'Strikes': strikes})

    for i in range(self.n_assets):
      self.data['Weight_{}'.format(i)] = weights[:,i]

    #save the dataframe to csv format
    return self.data

# %% [markdown]
# Our Goal is to Build and train a neural network model for pricing European Basket options under Black-Scholes assumptions. So our ground truth will be generated using  Black-Scholes function.

# %%
def simulate(n_assets=3, n_samples=10000, method="bs"):
  """
  Generates data based on the Datagen class
  args:
  - n_assets : number of assets contained in a Basket
  - n_samples : number of training examples
  - method : method used to compute the price it can be "mc" or "bs"
  """
  simulator = DataGen(3, n_samples=n_samples)
  simulated_prices = simulator.generate(method=method)
  return simulated_prices

# %%
# %time

data = simulate()
data
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# 10000
#            S/K  Maturity  Volatility      Rate        Labels      Prices  \
# 0     0.491688  0.398459    0.930119  0.036357  4.606438e+00   98.486437
# 1     0.503063  0.863532    0.566627  0.065148  3.985769e+00  100.330107
# 2     0.497556  0.823112    0.677723  0.063017  6.224637e+00  100.006295
# 3     0.511005  0.887433    0.602191  0.029589  4.949359e+00  101.842604
# 4     0.505688  0.540074    0.739791  0.029655  3.960615e+00  100.417851
# ...        ...       ...         ...       ...           ...         ...
# 9995  0.488641  0.969347    0.493520  0.027369  2.308491e+00   97.791559
# 9996  0.500026  0.468748    0.254593  0.051164  3.525524e-04  100.631824
# 9997  0.495976  0.786036    0.240267  0.054053  8.068046e-03   99.685022
# 9998  0.493424  0.946285    0.103212  0.096916  9.726524e-10   99.334278
# 9999  0.503747  1.093852    0.873329  0.071846  1.775254e+01  100.236134
#
#          Strikes  Weight_0  Weight_1  Weight_2
# 0     200.302776  0.382253  0.544924  0.072824
# 1     199.438576  0.274801  0.619750  0.105448
# 2     200.995017  0.223860  0.409920  0.366220
# 3     199.298837  0.218976  0.113948  0.667076
# 4     198.576615  0.548802  0.256225  0.194972
# ...          ...       ...       ...       ...
# 9995  200.129571  0.557312  0.433805  0.008882
# 9996  201.253340  0.584214  0.116826  0.298960
# 9997  200.987488  0.305485  0.359697  0.334819
# 9998  201.316337  0.383600  0.109214  0.507186
# 9999  198.981159  0.428332  0.026213  0.545455
#
# [10000 rows x 10 columns]

# %% [markdown]
# # Choosing Model Features
#
# Based on this paper : https://canopee-group.com/wp-content/uploads/2020/12/Machine-Learning-methods-Coperneec.pdf
#
# The important features to consider for the model construction while dealing with European basket call (BS)
# are :
#
# - Maturity
# - Risk
# - the ratio S/k (Moneyness)
# - Volatility
#
# **Methodology**
#
# Before building the model we will be splitting our data then :
# - Save train and test into csv formats
# - keep only the selected features
#
# **Model Description:**
#
# The model is build using the functional API of keras .
# It is composed of Dense layers, BatchNormalization layer and Dropout layer to prevent overfitting .
# The last layer is a Dense layer with 1 neuron as we are dealing with a regression problem and an activation function : relu because the Price option needs to be at least 0.

# %%
def split_data(data, split_ratio=0.7):
  """
  splits the data into train and test

  args:
  data : pd.Dataframe : represents simulated data
  split_ratio: the factor to spli data into train and test

  returns:
  x_train, y_train, x_test, y_test
  """
  train = data.iloc[:int(split_ratio * len(data)), :]
  test  = data.iloc[int(split_ratio * len(data)):, :]
  train.to_csv("train.csv", index=False)
  test.to_csv("test.csv", index=False)
  x_train, y_train = train.iloc[:, 0:4], train.iloc[:, 4]
  x_test, y_test = test.iloc[:, 0:4], test.iloc[:, 4]
  return x_train, y_train, x_test, y_test

x_train, y_train, x_test, y_test = split_data(data, split_ratio=0.7)

def build_model(epochs=EPOCHS):
  #build model using functional method
  input = Input(shape=(x_train.shape[1],))
  x = Dense(32, activation='relu')(input)
  x = Dropout(0.2)(x)
  x = Dense(64, activation='relu')(x)
  x = BatchNormalization()(x)
  output = Dense(1, activation='relu')(x)

  model = Model(inputs= input, outputs=output)
  return model

# %%
model = build_model()
model.compile(loss='mean_squared_error',
              optimizer="adam",
              metrics=["mean_squared_error"])

history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 18.8226 - mean_squared_error: 18.8226 - val_loss: 18.8238 - val_mean_squared_error: 18.8238
# Epoch 2/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.0085 - mean_squared_error: 2.0085 - val_loss: 8.1808 - val_mean_squared_error: 8.1808
# Epoch 3/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.4444 - mean_squared_error: 1.4444 - val_loss: 1.0247 - val_mean_squared_error: 1.0247
# Epoch 4/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5739 - mean_squared_error: 1.5739 - val_loss: 0.3709 - val_mean_squared_error: 0.3709
# Epoch 5/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.4071 - mean_squared_error: 1.4071 - val_loss: 0.4107 - val_mean_squared_error: 0.4107
# Epoch 6/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1242 - mean_squared_error: 1.1242 - val_loss: 0.1635 - val_mean_squared_error: 0.1635
# Epoch 7/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2318 - mean_squared_error: 1.2318 - val_loss: 1.1051 - val_mean_squared_error: 1.1051
# Epoch 8/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0455 - mean_squared_error: 1.0455 - val_loss: 1.1053 - val_mean_squared_error: 1.1053
# Epoch 9/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0337 - mean_squared_error: 1.0337 - val_loss: 0.6284 - val_mean_squared_error: 0.6284
# Epoch 10/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8296 - mean_squared_error: 0.8296 - val_loss: 1.4715 - val_mean_squared_error: 1.4715
# Epoch 11/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9974 - mean_squared_error: 0.9974 - val_loss: 0.9883 - val_mean_squared_error: 0.9883
# Epoch 12/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8744 - mean_squared_error: 0.8744 - val_loss: 1.5399 - val_mean_squared_error: 1.5399
# Epoch 13/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8859 - mean_squared_error: 0.8859 - val_loss: 2.0170 - val_mean_squared_error: 2.0170
# Epoch 14/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8424 - mean_squared_error: 0.8424 - val_loss: 1.0624 - val_mean_squared_error: 1.0624
# Epoch 15/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8790 - mean_squared_error: 0.8790 - val_loss: 1.3771 - val_mean_squared_error: 1.3771
# Epoch 16/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7902 - mean_squared_error: 0.7902 - val_loss: 1.6737 - val_mean_squared_error: 1.6737
# Epoch 17/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8511 - mean_squared_error: 0.8511 - val_loss: 1.2260 - val_mean_squared_error: 1.2260
# Epoch 18/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8093 - mean_squared_error: 0.8093 - val_loss: 1.0837 - val_mean_squared_error: 1.0837
# Epoch 19/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6284 - mean_squared_error: 0.6284 - val_loss: 2.9659 - val_mean_squared_error: 2.9659
# Epoch 20/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7514 - mean_squared_error: 0.7514 - val_loss: 1.8019 - val_mean_squared_error: 1.8019
# Epoch 21/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6448 - mean_squared_error: 0.6448 - val_loss: 1.7173 - val_mean_squared_error: 1.7173
# Epoch 22/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6373 - mean_squared_error: 0.6373 - val_loss: 1.2738 - val_mean_squared_error: 1.2738
# Epoch 23/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5985 - mean_squared_error: 0.5985 - val_loss: 2.3593 - val_mean_squared_error: 2.3593
# Epoch 24/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5486 - mean_squared_error: 0.5486 - val_loss: 1.1918 - val_mean_squared_error: 1.1918
# Epoch 25/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6191 - mean_squared_error: 0.6191 - val_loss: 1.2819 - val_mean_squared_error: 1.2819
# Epoch 26/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6109 - mean_squared_error: 0.6109 - val_loss: 1.5289 - val_mean_squared_error: 1.5289
# Epoch 27/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5823 - mean_squared_error: 0.5823 - val_loss: 2.7233 - val_mean_squared_error: 2.7233
# Epoch 28/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6578 - mean_squared_error: 0.6578 - val_loss: 1.8538 - val_mean_squared_error: 1.8538
# Epoch 29/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7386 - mean_squared_error: 0.7386 - val_loss: 0.9820 - val_mean_squared_error: 0.9820
# Epoch 30/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6068 - mean_squared_error: 0.6068 - val_loss: 1.0496 - val_mean_squared_error: 1.0496
# Epoch 31/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6402 - mean_squared_error: 0.6402 - val_loss: 1.1273 - val_mean_squared_error: 1.1273
# Epoch 32/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.5063 - mean_squared_error: 0.5063 - val_loss: 2.4179 - val_mean_squared_error: 2.4179
# Epoch 33/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5510 - mean_squared_error: 0.5510 - val_loss: 0.7431 - val_mean_squared_error: 0.7431
# Epoch 34/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7240 - mean_squared_error: 0.7240 - val_loss: 1.5076 - val_mean_squared_error: 1.5076
# Epoch 35/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6499 - mean_squared_error: 0.6499 - val_loss: 1.4095 - val_mean_squared_error: 1.4095
# Epoch 36/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5677 - mean_squared_error: 0.5677 - val_loss: 1.8209 - val_mean_squared_error: 1.8209
# Epoch 37/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5403 - mean_squared_error: 0.5403 - val_loss: 2.1578 - val_mean_squared_error: 2.1578
# Epoch 38/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7009 - mean_squared_error: 0.7009 - val_loss: 1.2490 - val_mean_squared_error: 1.2490
# Epoch 39/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6229 - mean_squared_error: 0.6229 - val_loss: 1.4276 - val_mean_squared_error: 1.4276
# Epoch 40/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5916 - mean_squared_error: 0.5916 - val_loss: 2.3124 - val_mean_squared_error: 2.3124
# Epoch 41/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5452 - mean_squared_error: 0.5452 - val_loss: 1.9544 - val_mean_squared_error: 1.9544
# Epoch 42/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.5687 - mean_squared_error: 0.5687 - val_loss: 1.0309 - val_mean_squared_error: 1.0309
# Epoch 43/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6449 - mean_squared_error: 0.6449 - val_loss: 1.7847 - val_mean_squared_error: 1.7847
# Epoch 44/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4785 - mean_squared_error: 0.4785 - val_loss: 2.1999 - val_mean_squared_error: 2.1999
# Epoch 45/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5067 - mean_squared_error: 0.5067 - val_loss: 1.7191 - val_mean_squared_error: 1.7191
# Epoch 46/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5817 - mean_squared_error: 0.5817 - val_loss: 1.5832 - val_mean_squared_error: 1.5832
# Epoch 47/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6046 - mean_squared_error: 0.6046 - val_loss: 2.3589 - val_mean_squared_error: 2.3589
# Epoch 48/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5849 - mean_squared_error: 0.5849 - val_loss: 1.6943 - val_mean_squared_error: 1.6943
# Epoch 49/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6357 - mean_squared_error: 0.6357 - val_loss: 1.6212 - val_mean_squared_error: 1.6212
# Epoch 50/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6580 - mean_squared_error: 0.6580 - val_loss: 2.2222 - val_mean_squared_error: 2.2222

# %% [markdown]
# Compute Model Predictions on test data

# %%
start = time.time()
predictions = model.predict(x_test)
end = time.time()
print(f"Runtime of the model on test set is {end - start}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Runtime of the model on test set is 0.6971065998077393

# %% [markdown]
# # Optional : Model Performance plotting

# %%
def plot_performance(history):
  plt.plot(history.history['mean_squared_error'])
  plt.plot(history.history['val_mean_squared_error'])
  plt.ylabel('MAE')
  plt.xlabel("epoch")
  plt.legend(['train', 'test'])
  plt.savefig("NN_train.png")
  plt.show();

# %%
plot_performance(history);

# %%
print("maximum train option price :" , y_train.max())
print("mean train option price : " , np.mean(y_train))
# Out:
# maximum train option price : 23.426916769083284
# mean train option price :  3.338765142593513

# %% [markdown]
# We notice that compared to the values of the dataset the MEA for the training data is pretty low for this simple regression model .

# %%
#Plot test labels distribution
sns.displot(y_test)

# %%
#Plot prediction distribution
sns.displot(predictions)

# %% [markdown]
# # Compare prices to a traditional numerical solver such as Monte-Carlo, Finite Difference or any other methodology you may deem applicable.

# %% [markdown]
# In this part we will be using Monte Carlo for computing Basket option price.
# we will be working on testing set . So we will load the test set that we saved earlier.

# %% [markdown]
# **Methodology:**
#
# For making using of the MC simulations I used a function defined in this notebook  that uses MC for a call option : https://github.com/shrentseng/Numerical-methods-for-option-pricing/blob/main/Monte%20Carlo%20simulation%20option%20pricing.ipynb
# But as I am dealing with a Basket so when computing the payoff I need to pay attention to the weights.

# %%
import os
if os.path.exists("test.csv"):
  print("Downloading test csv file .......")
  test = pd.read_csv("test.csv")
# Out:
# Downloading test csv file .......

# %%
test.head()
# Out:
#         S/K  Maturity  Volatility      Rate     Labels      Prices  \
# 0  0.507991  0.463324    0.243154  0.082186   0.000301  101.655323
# 1  0.508576  0.635094    0.817289  0.069494   7.707559  101.207550
# 2  0.508737  1.050566    0.700688  0.057758  10.255315  100.414517
# 3  0.507294  0.271774    0.707246  0.022394   0.688233  100.603139
# 4  0.504209  0.345634    0.832051  0.072950   2.756399  100.798820
#
#       Strikes  Weight_0  Weight_1  Weight_2
# 0  200.112546  0.391859  0.055265  0.552876
# 1  199.001799  0.401740  0.248720  0.349540
# 2  197.380027  0.268942  0.512476  0.218582
# 3  198.313378  0.176584  0.682471  0.140945
# 4  199.914617  0.506530  0.150820  0.342650

# %%
#Define a Monte carlo MC price empty list
# %time
start = time.time()
mc_prices = []
for i in range(test.shape[0]):
    basket = BasketOption(
        test.iloc[i,7:].to_numpy(),
        test.iloc[i].Prices,
        test.iloc[i].Volatility,
        CORR,
        test.iloc[i].Strikes,
        test.iloc[i].Maturity,
        test.iloc[i].Rate
    )
    mc_prices.append(basket.get_mc())
end = time.time()
print(f"Runtime of MC is : .... {end - start}")
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# Runtime of MC is : .... 12.404102802276611

# %% [markdown]
# # Compare to the case of 1 asset
#
# In the case of 1 asset the correlation matrix takes one value :
#
# So we will have same work as before with :
#
# - corr = np.array([[1,]])
# - n_assets = 1

# %%
len(test)
# Out:
# 3000

# %% [markdown]
# Summary :
#
# The Main Goal of the client is explore novel methodologies for accelerating the pricing of exotic derivatives. The Client cares a lot about the time that an algorithm consumes to compute Option Price
#
# From  our experiment : with 10 000 data points and with 3000 data points on the test set the Neural network model needs  0.12 seconds to run and the MC algorithm needs 9.85 seconds to run.
